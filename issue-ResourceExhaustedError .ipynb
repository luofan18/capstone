# %%
import keras
from keras import backend as K
K.clear_session()
# Out:
# Using TensorFlow backend.

# %%
from keras.applications.vgg16 import VGG16
from keras.models import Model
for i in range(1000):
    if i % 1 == 0:
        print 'init {}th model'.format(i)
    model = VGG16(weights='imagenet', include_top=False, input_shape=(4000,3000,3))
# Out:
# init 0th model
# init 1th model
# init 2th model
# init 3th model
# init 4th model
# init 5th model
# init 6th model
# init 7th model
# init 8th model
# init 9th model
# init 10th model
# init 11th model
# init 12th model
# init 13th model
# init 14th model
# init 15th model
# init 16th model
# init 17th model
# init 18th model
# init 19th model
# init 20th model
# init 21th model
# init 22th model
# init 23th model
# init 24th model
# init 25th model
# init 26th model
# init 27th model
# init 28th model
# init 29th model
# init 30th model
# init 31th model
# init 32th model
# init 33th model
# init 34th model
# init 35th model
# init 36th model
# init 37th model
# init 38th model
# init 39th model
# init 40th model
# init 41th model
# init 42th model
# init 43th model
# init 44th model
# init 45th model
# init 46th model
# init 47th model
# init 48th model
# init 49th model
# init 50th model
# init 51th model
# init 52th model
# init 53th model
# init 54th model
# init 55th model
# init 56th model
# init 57th model
# init 58th model
# init 59th model
# init 60th model
# init 61th model
# init 62th model
# init 63th model
# init 64th model
# init 65th model
# init 66th model
# init 67th model
# init 68th model
# init 69th model
# init 70th model
# init 71th model
# init 72th model
# init 73th model
# init 74th model
# init 75th model
# init 76th model
# init 77th model
# init 78th model
# init 79th model
# init 80th model
# init 81th model
# init 82th model
# init 83th model
# init 84th model
# init 85th model
# init 86th model
# init 87th model
# init 88th model
# init 89th model
# init 90th model
# init 91th model
# init 92th model
# init 93th model
# init 94th model
# init 95th model
# init 96th model
# init 97th model
# init 98th model
# init 99th model
# init 100th model
# init 101th model
# init 102th model
# init 103th model
# init 104th model
# init 105th model
# init 106th model
# init 107th model
# init 108th model
# init 109th model
# init 110th model
# init 111th model
# init 112th model
# init 113th model
# init 114th model
# init 115th model
# init 116th model
# init 117th model
# init 118th model
# init 119th model
# init 120th model
# init 121th model
# init 122th model
# init 123th model
# init 124th model
# init 125th model
# init 126th model
# init 127th model
# init 128th model
# init 129th model
# init 130th model
# init 131th model
# init 132th model
# init 133th model
# init 134th model
# init 135th model
# init 136th model
# init 137th model
# init 138th model
# init 139th model
# init 140th model
# init 141th model
# init 142th model
# init 143th model
# init 144th model
# init 145th model
# init 146th model
# init 147th model
# init 148th model
# init 149th model
# init 150th model
# init 151th model
# init 152th model
# init 153th model
# init 154th model
# init 155th model
# init 156th model
# init 157th model
# init 158th model
# init 159th model
# init 160th model
# init 161th model
# init 162th model
# init 163th model
# init 164th model
# init 165th model
# init 166th model
# init 167th model
# init 168th model
# init 169th model
# init 170th model
# init 171th model
# init 172th model
# init 173th model
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-2-12e17370d528> in <module>()
#       4     if i % 1 == 0:
#       5         print 'init {}th model'.format(i)
# ----> 6     model = VGG16(weights='imagenet', include_top=False, input_shape=(4000,3000,3))
#
# /usr/local/lib/python2.7/dist-packages/keras/applications/vgg16.pyc in VGG16(include_top, weights, input_tensor, input_shape, classes)
#     161                                         TF_WEIGHTS_PATH_NO_TOP,
#     162                                         cache_subdir='models')
# --> 163             model.load_weights(weights_path)
#     164             if K.backend() == 'theano':
#     165                 convert_all_kernels_in_model(model)
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/topology.pyc in load_weights(self, filepath, by_name)
#    2706             self.load_weights_from_hdf5_group_by_name(f)
#    2707         else:
# -> 2708             self.load_weights_from_hdf5_group(f)
#    2709
#    2710         if hasattr(f, 'close'):
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/topology.pyc in load_weights_from_hdf5_group(self, f)
#    2792                         weight_values[0] = w
#    2793                 weight_value_tuples += zip(symbolic_weights, weight_values)
# -> 2794             K.batch_set_value(weight_value_tuples)
#    2795
#    2796     def load_weights_from_hdf5_group_by_name(self, f):
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in batch_set_value(tuples)
#    1879             assign_ops.append(assign_op)
#    1880             feed_dict[assign_placeholder] = value
# -> 1881         get_session().run(assign_ops, feed_dict=feed_dict)
#    1882
#    1883
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# InternalError: Dst tensor is not initialized.
# 	 [[Node: _recv_Placeholder_4520_0/_17999 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/gpu:0", send_device="/job:localhost/replica:0/task:0/cpu:0", send_device_incarnation=1, tensor_name="edge_76__recv_Placeholder_4520_0", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/gpu:0"]()]]
# 	 [[Node: Assign_4505/_18059 = _Recv[_start_time=0, client_terminated=false, recv_device="/job:localhost/replica:0/task:0/cpu:0", send_device="/job:localhost/replica:0/task:0/gpu:0", send_device_incarnation=1, tensor_name="edge_93_Assign_4505", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"]()]]

# %%
K.clear_session()
